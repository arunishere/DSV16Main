# %%
'''

1. Line Chart (Trends)
2. Histogram (Frequencies)
3. Scatter Plot (Relationships)
4. Box plot (Dispersion)
5. Bar Plot
6. Volin Plot
7. Misc - HeatMap

'''

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Line Chart

# %%
df = pd.DataFrame()
df['Date'] = pd.date_range('01-01-2025', '03-31-2025', freq='D')
df['India Price'] = np.abs(np.random.randn(90))
df['Aus Price'] = np.abs(np.random.randn(90))

# %%
df2 = df.copy()

# %%
df2
# Out:
#          Date  India Price  Aus Price
# 0  2025-01-01     0.058096   0.430713
# 1  2025-01-02     0.215199   0.724985
# 2  2025-01-03     0.986398   0.765064
# 3  2025-01-04     0.672909   0.471327
# 4  2025-01-05     0.103368   0.049857
# ..        ...          ...        ...
# 85 2025-03-27     1.163262   0.745644
# 86 2025-03-28     0.251103   0.223839
# 87 2025-03-29     0.372058   0.038857
# 88 2025-03-30     0.261289   1.859258
# 89 2025-03-31     0.894498   0.185653
#
# [90 rows x 3 columns]

# %%
plt.figure(figsize=(15,5))
plt.plot(df2['Date'], df['India Price'])
plt.title('Daily Prices($)')
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Price($)')
plt.show()

# %%
df2['India Price'] = df2['India Price'] * 1.2
df2['Aus Price'] = df2['India Price'] * 0.4

# %%
plt.figure(figsize=(15,5))
plt.plot(df2['Date'], df2['India Price'])
plt.plot(df2['Date'], df2['Aus Price'])
plt.title('Daily Prices($)')
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Price($)')
plt.show()

# %%
df = pd.DataFrame()
df['Date'] = pd.date_range(start='01-01-2025 00:00:00', end='01-07-2025 00:00:00', freq='H')
len_size = df.shape[0]
df['Temperature'] = np.abs(np.random.randn(len_size))


df2 = df.copy()

df2
# Out:
# /var/folders/jr/pfy34jh93sb8cn2hnjc2k73w0000gn/T/ipykernel_72315/2898049365.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df['Date'] = pd.date_range(start='01-01-2025 00:00:00', end='01-07-2025 00:00:00', freq='H')
#                    Date  Temperature
# 0   2025-01-01 00:00:00     1.666350
# 1   2025-01-01 01:00:00     1.385689
# 2   2025-01-01 02:00:00     1.299294
# 3   2025-01-01 03:00:00     0.905920
# 4   2025-01-01 04:00:00     0.334447
# ..                  ...          ...
# 140 2025-01-06 20:00:00     0.367631
# 141 2025-01-06 21:00:00     0.489453
# 142 2025-01-06 22:00:00     1.802505
# 143 2025-01-06 23:00:00     1.331816
# 144 2025-01-07 00:00:00     0.605645
#
# [145 rows x 2 columns]

# %%
plt.figure(figsize=(15,5))
plt.plot(df2['Date'], df['Temperature'])
plt.title('Daily Prices($)')
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Price($)')
plt.show()

# %%
points = 50
time = np.linspace(0, 10, points)
temp = np.random.uniform(low=22, high=24, size=points)

plt.figure(figsize=(15,5))
plt.plot(time, temp)
plt.title('Daily Prices($)')
plt.grid(True)
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.show()

# %%
points = 50
time = np.linspace(0, 10, points)
temp = np.sin(time)
temp_1  = np.sin(time) + 1.2
temp_2  = np.sin(time) + 0.6
plt.figure(figsize=(15,5))
plt.plot(time, temp)
plt.plot(time, temp_1, color='r', linestyle="--")
plt.plot(time, temp_2)
plt.title('Daily Prices($)')
plt.grid(True)
plt.legend(['Sin(x)', 'Sin(x)+1.5','Sin(x)+0.75'])
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x=time, y=temp)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Histogram Chart

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Orange Quality Data.csv')

# %%
df.head(5)
# Out:
#    Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0        7.5         180              12.0           3.2             2.0
# 1        8.2         220              10.5           3.4             3.0
# 2        6.8         150              14.0           3.0             1.0
# 3        9.0         250               8.5           3.8             4.0
# 4        8.5         210              11.5           3.3             2.5
#
#    HarvestTime (days)  Ripeness (1-5)         Color       Variety  \
# 0                  10             4.0        Orange      Valencia
# 1                  14             4.5   Deep Orange         Navel
# 2                   7             5.0  Light Orange     Cara Cara
# 3                  21             3.5    Orange-Red  Blood Orange
# 4                  12             5.0        Orange        Hamlin
#
#   Blemishes (Y/N)  Quality (1-5)
# 0               N            4.0
# 1               N            4.5
# ...

# %%
# Frequency - Occurence
# Numbers (Eg. Group - "16-18", "19-21")

plt.figure(figsize=(8,5))
plt.hist(df['HarvestTime (days)'])

plt.show()

# %%
df['HarvestTime (days)']
# Out:
# 0      10
# 1      14
# 2       7
# 3      21
# 4      12
#        ..
# 236    13
# 237    20
# 238    13
# 239    23
# 240    21
# Name: HarvestTime (days), Length: 241, dtype: int64

# %%
df1 = df.copy()

df1['bin'] = pd.cut(df['HarvestTime (days)'], 3, right=True)

# %%
df1['bin'].unique()
# Out:
# [(3.979, 11.0], (11.0, 18.0], (18.0, 25.0]]
# Categories (3, interval[float64, right]): [(3.979, 11.0] < (11.0, 18.0] < (18.0, 25.0]]

# %%
df1.groupby(by='bin')['bin'].count()
# Out:
# /var/folders/jr/pfy34jh93sb8cn2hnjc2k73w0000gn/T/ipykernel_82980/1633139970.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df1.groupby(by='bin')['bin'].count()
# bin
# (3.979, 11.0]    68
# (11.0, 18.0]     96
# (18.0, 25.0]     77
# Name: bin, dtype: int64

# %%
df1.head(10)
# Out:
#    Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0        7.5         180              12.0           3.2             2.0
# 1        8.2         220              10.5           3.4             3.0
# 2        6.8         150              14.0           3.0             1.0
# 3        9.0         250               8.5           3.8             4.0
# 4        8.5         210              11.5           3.3             2.5
# 5        6.7         126               9.1           3.0             2.0
# 6        7.2         160               9.0           3.5             3.5
# 7        6.5         130              13.5           2.8             1.5
# 8        8.8         240               7.5           4.0             5.0
# 9        7.8         190              12.0           3.1             2.0
#
#    HarvestTime (days)  Ripeness (1-5)          Color           Variety  \
# 0                  10             4.0         Orange          Valencia
# ...

# %%
pd.cut(df['HarvestTime (days)'], 3, right=True)
# Out:
# 0      (3.979, 11.0]
# 1       (11.0, 18.0]
# 2      (3.979, 11.0]
# 3       (18.0, 25.0]
# 4       (11.0, 18.0]
#            ...
# 236     (11.0, 18.0]
# 237     (18.0, 25.0]
# 238     (11.0, 18.0]
# 239     (18.0, 25.0]
# 240     (18.0, 25.0]
# Name: HarvestTime (days), Length: 241, dtype: category
# Categories (3, interval[float64, right]): [(3.979, 11.0] < (11.0, 18.0] < (18.0, 25.0]]

# %%
plt.figure(figsize=(8,5))
plt.hist(df['HarvestTime (days)'], bins=3)

plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['HarvestTime (days)'], bins=5)

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Weight (g)'], bins=5)

plt.show()

# %% [markdown]
# ## Bar Chart

# %%
df_group = df.groupby(by='Color')['Weight (g)'].mean().reset_index()

# %%
df_group
# Out:
#            Color  Weight (g)
# 0    Deep Orange  208.973333
# 1   Light Orange  191.375000
# 2         Orange  206.763158
# 3     Orange-Red  221.872727
# 4  Yellow-Orange  161.666667

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=df_group['Color'], y=df_group['Weight (g)'])

plt.show()

# %%
df_group = df.groupby(by='Color')['Size (cm)'].mean().reset_index()

plt.figure(figsize=(8,5))
sns.barplot(x=df_group['Color'], y=df_group['Size (cm)'])

plt.show()

# %%
df_group = df.groupby(by='Color')['Size (cm)'].mean().reset_index()
plt.figure(figsize=(8,5))
sns.barplot(y=df_group['Color'], x=df_group['Size (cm)'])
plt.show()

# %%
df_group = df.groupby(by='Variety')['Size (cm)'].mean().reset_index()
plt.figure(figsize=(8,8))
sns.barplot(y=df_group['Variety'], x=df_group['Size (cm)'])
plt.show()

# %% [markdown]
# ## Box Plot

# %%
df.columns
# Out:
# Index(['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)',
#        'Softness (1-5)', 'HarvestTime (days)', 'Ripeness (1-5)', 'Color',
#        'Variety', 'Blemishes (Y/N)', 'Quality (1-5)'],
#       dtype='object')

# %%
90/150
# Out:
# 0.6

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y=df['Weight (g)'])
plt.show()

# %%
print('Minimim Weight:', df['Weight (g)'].min())
print('Maximum Weight:', df['Weight (g)'].max())
print('Maximum Weight:', df['Weight (g)'].median())
print('1st Quantile:', df['Weight (g)'].quantile(0.25))
print('2nd Quantile:', df['Weight (g)'].quantile(0.50))
print('3nd Quantile:', df['Weight (g)'].quantile(0.75))
# Out:
# Minimim Weight: 100
# Maximum Weight: 300
# Maximum Weight: 205.0
# 1st Quantile: 155.0
# 2nd Quantile: 205.0
# 3nd Quantile: 252.0

# %%
## Plotly

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y=df['Weight (g)'], x=df['Color'])
plt.show()

# %%
241/2
# Out:
# 120.5

# %%
df[df['Weight (g)'] < 205.0]
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0          7.5         180              12.0           3.2             2.0
# 2          6.8         150              14.0           3.0             1.0
# 5          6.7         126               9.1           3.0             2.0
# 6          7.2         160               9.0           3.5             3.5
# 7          6.5         130              13.5           2.8             1.5
# ..         ...         ...               ...           ...             ...
# 230        9.0         147              15.6           3.4             2.0
# 231        9.5         131               6.1           3.3             5.0
# 235        8.5         130               8.1           3.6             3.0
# 236        8.0         194              10.9           3.6             5.0
# 238        7.5         196              15.7           3.0             3.0
#
# ...

# %%
df[df['Weight (g)'] > 205.0]
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 1          8.2         220              10.5           3.4             3.0
# 3          9.0         250               8.5           3.8             4.0
# 4          8.5         210              11.5           3.3             2.5
# 8          8.8         240               7.5           4.0             5.0
# 10         9.5         270               6.0           4.2             4.5
# ..         ...         ...               ...           ...             ...
# 233        8.2         249              12.8           3.8             3.0
# 234        8.6         251              11.5           3.8             5.0
# 237        7.4         275               8.5           3.5             5.0
# 239        7.2         251               9.8           4.3             3.0
# 240        7.3         282              10.5           2.9             4.0
#
# ...

# %%
df.shape
# Out:
# (241, 11)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y=df['Quality (1-5)'])
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
df.columns
# Out:
# Index(['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)',
#        'Softness (1-5)', 'HarvestTime (days)', 'Ripeness (1-5)', 'Color',
#        'Variety', 'Blemishes (Y/N)', 'Quality (1-5)'],
#       dtype='object')

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x=df['Size (cm)'],y=df['Weight (g)'], marker='x', s=40)
plt.axhline(y=195, color='red',linestyle='--')

# plt.grid(True)
plt.axvline(x=7.8, color='red',linestyle='--')
plt.text(x=6.4, y=210, s='Quadrant II')
plt.text(x=9.2, y=210, s='Quadrant I')
plt.text(x=6.4, y=100, s='Quadrant III')
plt.text(x=9.2, y=100, s='Quadrant IV')
plt.title('Bi-Variate Analysis (Size vs Weights)')
plt.show()

# %%
df1 = df[
    (df['Size (cm)'] > 8.0) & 
    (df['Weight (g)'] < 175)
    ]

# %%
df1
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 99         8.5         158              11.2          3.60             4.0
# 101        9.3         127              14.2          3.72             3.0
# 102        8.9         118               8.1          3.32             5.0
# 110        9.9         152               6.4          3.33             4.0
# 121        8.2         169              11.8          2.92             4.0
# 126        9.7         108               8.6          3.58             2.0
# 137        9.8         143              11.0          3.65             3.0
# 144        8.2         129              10.0          3.60             5.0
# 148        9.2         139              14.0          3.70             2.0
# 157        9.7         126               9.1          4.10             1.0
# 163        9.0         126              11.5          4.30             3.0
# ...

# %%
df_without_outlier = df.drop(df1.index,axis=0)

# %%
df_without_outlier.describe()
# Out:
#         Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# count  222.000000  222.000000        222.000000    222.000000      222.000000
# mean     7.737387  210.765766         10.911261      3.459865        3.074324
# std      1.052125   55.097602          2.749876      0.420412        1.324198
# min      6.000000  100.000000          5.500000      2.800000        1.000000
# 25%      6.900000  170.000000          8.500000      3.117500        2.000000
# 50%      7.700000  212.500000         11.000000      3.400000        3.000000
# 75%      8.500000  257.750000         13.400000      3.800000        4.000000
# max     10.000000  300.000000         16.000000      4.400000        5.000000
#
#        HarvestTime (days)  Ripeness (1-5)  Quality (1-5)
# count          222.000000      222.000000     222.000000
# mean            15.207207        3.619369       3.833333
# std              5.374007        1.178784       1.007513
# ...

# %%
df1.describe()
# Out:
#        Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# count  19.000000   19.000000         19.000000     19.000000       19.000000
# mean    9.100000  139.263158         10.868421      3.637895        3.052632
# std     0.573488   16.161828          2.959176      0.403024        1.352926
# min     8.200000  108.000000          6.100000      2.900000        1.000000
# 25%     8.650000  128.000000          8.350000      3.365000        2.000000
# 50%     9.000000  139.000000         11.200000      3.600000        3.000000
# 75%     9.650000  149.000000         13.400000      3.810000        4.000000
# max     9.900000  169.000000         15.600000      4.300000        5.000000
#
#        HarvestTime (days)  Ripeness (1-5)  Quality (1-5)
# count           19.000000       19.000000      19.000000
# mean            16.947368        3.368421       3.631579
# std              4.515082        1.498537       1.103556
# ...

# %% [markdown]
# ## Voilin Plot

# %%
df = pd.read_csv('Orange Quality Data.csv')

# %%
df
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0          7.5         180              12.0           3.2             2.0
# 1          8.2         220              10.5           3.4             3.0
# 2          6.8         150              14.0           3.0             1.0
# 3          9.0         250               8.5           3.8             4.0
# 4          8.5         210              11.5           3.3             2.5
# ..         ...         ...               ...           ...             ...
# 236        8.0         194              10.9           3.6             5.0
# 237        7.4         275               8.5           3.5             5.0
# 238        7.5         196              15.7           3.0             3.0
# 239        7.2         251               9.8           4.3             3.0
# 240        7.3         282              10.5           2.9             4.0
#
# ...

# %% [markdown]
# ![output.png](attachment:output.png)

# %%
df.columns
# Out:
# Index(['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)',
#        'Softness (1-5)', 'HarvestTime (days)', 'Ripeness (1-5)', 'Color',
#        'Variety', 'Blemishes (Y/N)', 'Quality (1-5)'],
#       dtype='object')

# %%
plt.figure(figsize=(8,5))

sns.violinplot(y=df['Brix (Sweetness)'], x=df['Color'])
plt.show()

# %% [markdown]
# ## Heatmap

# %%
df
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0          7.5         180              12.0           3.2             2.0
# 1          8.2         220              10.5           3.4             3.0
# 2          6.8         150              14.0           3.0             1.0
# 3          9.0         250               8.5           3.8             4.0
# 4          8.5         210              11.5           3.3             2.5
# ..         ...         ...               ...           ...             ...
# 236        8.0         194              10.9           3.6             5.0
# 237        7.4         275               8.5           3.5             5.0
# 238        7.5         196              15.7           3.0             3.0
# 239        7.2         251               9.8           4.3             3.0
# 240        7.3         282              10.5           2.9             4.0
#
# ...

# %%
df_1 = df[['Size (cm)', 'Weight (g)']]

# %%
sns.heatmap(df_1)
# Out:
# <Axes: >
